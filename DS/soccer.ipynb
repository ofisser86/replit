# %%
import pandas as pd
data_frame = pd.read_csv('data/data.csv')
data_frame.shape
# Out:
# (18207, 89)

# %%
data_frame.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data_frame.values
# Out:
# array([[0, 158023, 'L. Messi', ..., 14.0, 8.0, '€226.5M'],
#        [1, 20801, 'Cristiano Ronaldo', ..., 14.0, 11.0, '€127.1M'],
#        [2, 190871, 'Neymar Jr', ..., 15.0, 11.0, '€228.1M'],
#        ...,
#        [18204, 241638, 'B. Worman', ..., 6.0, 13.0, '€165K'],
#        [18205, 246268, 'D. Walker-Rice', ..., 8.0, 9.0, '€143K'],
#        [18206, 246269, 'G. Nugent', ..., 12.0, 9.0, '€165K']],
#       dtype=object)

# %%
data_frame["Age"].hist()

# %%
data_frame["Name"].head(20)
# Out:
# 0              L. Messi
# 1     Cristiano Ronaldo
# 2             Neymar Jr
# 3                De Gea
# 4          K. De Bruyne
# 5             E. Hazard
# 6             L. Modrić
# 7             L. Suárez
# 8          Sergio Ramos
# 9              J. Oblak
# 10       R. Lewandowski
# 11             T. Kroos
# 12             D. Godín
# 13          David Silva
# 14             N. Kanté
# 15            P. Dybala
# 16              H. Kane
# 17         A. Griezmann
# 18        M. ter Stegen
# 19          T. Courtois
# Name: Name, dtype: object

# %%
data_frame[data_frame["Age"]>40].head()
# Out:
#        Unnamed: 0      ID         Name  Age  \
# 1120         1120  156092    J. Villar   41
# 4228         4228    3665     B. Nivet   41
# 4741         4741  140029     O. Pérez   45
# 7225         7225  142998     C. Muñoz   41
# 10545       10545  140183  S. Narazaki   42
#
#                                                 Photo Nationality  \
# 1120   https://cdn.sofifa.org/players/4/19/156092.png    Paraguay
# 4228     https://cdn.sofifa.org/players/4/19/3665.png      France
# 4741   https://cdn.sofifa.org/players/4/19/140029.png      Mexico
# 7225   https://cdn.sofifa.org/players/4/19/142998.png   Argentina
# 10545  https://cdn.sofifa.org/players/4/19/140183.png       Japan
#
#                                        Flag  Overall  Potential  \
# 1120    https://cdn.sofifa.org/flags/58.png       77         77
# 4228    https://cdn.sofifa.org/flags/18.png       71         71
# 4741    https://cdn.sofifa.org/flags/83.png       71         71
# ...

# %%
data_frame[data_frame["Nationality"]== "Ukraine"].head(20)
# Out:
#       Unnamed: 0      ID            Name  Age  \
# 288          288  187754          Marlos   30
# 453          453  206413   T. Stepanenko   28
# 484          484  195861    Y. Rakitskyi   28
# 486          486  194794   A. Yarmolenko   28
# 555          555  244369    V. Tsygankov   20
# 637          637  200641  Y. Konoplyanka   28
# 916          916  220948    S. Sydorchuk   27
# 932          932  231969  R. Malinovskyi   25
# 954          954  142902       A. Pyatov   34
# 983          983  206411      D. Garmash   28
# 1248        1248  232226        D. Boyko   30
# 1267        1267  224811       I. Ordets   25
# 1359        1359  176483  D. Chygrynskyi   31
# 1544        1544  243952        A. Lunin   19
# 1728        1728  206414     S. Kryvtsov   27
# 1752        1752  206424     M. Morozyuk   30
# 1759        1759  206427        B. Butko   27
# 1875        1875  244373    V. Buyalskyi   25
# 2104        2104  195860   Y. Khacheridi   30
# ...

# %%
data_frame[data_frame["Name"]== "Cristiano Ronaldo"].head()
# Out:
#    Unnamed: 0     ID               Name  Age  \
# 1           1  20801  Cristiano Ronaldo   33
#
#                                            Photo Nationality  \
# 1  https://cdn.sofifa.org/players/4/19/20801.png    Portugal
#
#                                   Flag  Overall  Potential      Club  ...  \
# 1  https://cdn.sofifa.org/flags/38.png       94         94  Juventus  ...
#
#   Composure Marking StandingTackle  SlidingTackle GKDiving  GKHandling  \
# 1      95.0    28.0           31.0           23.0      7.0        11.0
#
#    GKKicking  GKPositioning GKReflexes Release Clause
# 1       15.0           14.0       11.0        €127.1M
#
# [1 rows x 89 columns]

# %%
df1 = pd.DataFrame(data_frame, columns=['Name', 'Wage', 'Value'])
def value_to_float(x):
    if type(x) == float or type(x) == int:
        return x
    if 'K' in x:
        if len(x) > 1:
            return float(x.replace('K', '')) * 1000
        return 1000.0
    if 'M' in x:
        if len(x) > 1:
            return float(x.replace('M', '')) * 1000000
        return 1000000.0
    if 'B' in x:
        return float(x.replace('B', '')) * 1000000000
    return 0.0
wage = df1['Wage'].replace('[\€,]', ' ', regex=True).apply(value_to_float)
value = df1['Value'].replace('[\€,]', ' ', regex=True).apply(value_to_float)
df1
df1[df1["Name"]== "Cristiano Ronaldo"].head()
# Out:
#                 Name   Wage Value
# 1  Cristiano Ronaldo  €405K  €77M

# %%
df1['Wage'] = wage
df1['Value'] = value
df1['difference'] = df1['Value'] - df1['Wage']
df1.sort_values('difference', ascending=False)
# Out:
#                Name      Wage        Value   difference
# 2         Neymar Jr  290000.0  118500000.0  118210000.0
# 0          L. Messi  565000.0  110500000.0  109935000.0
# 4      K. De Bruyne  355000.0  102000000.0  101645000.0
# 5         E. Hazard  340000.0   93000000.0   92660000.0
# 15        P. Dybala  205000.0   89000000.0   88795000.0
# ...             ...       ...          ...          ...
# 17752   S. Phillips    1000.0          0.0      -1000.0
# 12192  H. Sulaimani    3000.0          0.0      -3000.0
# 3550    S. Nakamura    4000.0          0.0      -4000.0
# 4228       B. Nivet    5000.0          0.0      -5000.0
# 864          Hilton   18000.0          0.0     -18000.0
#
# [18207 rows x 4 columns]

# %%
import seaborn as sns
sns.set()

graph = sns.scatterplot(x='Wage', y='Value', data=df1)
graph

# %%
from bokeh.plotting import figure, show
from bokeh.models import HoverTool

TOOLTIPS = HoverTool(tooltips=[
    ("index", "$index"),
    ("(Wage,Value)", "(@Wage, @Value)"),
    ("Name", "@Name")]
)

p = figure(title="Soccer 2019", x_axis_label='Wage', y_axis_label='Value', plot_width=700, plot_height=700, tools=[TOOLTIPS])
p.circle('Wage', 'Value', size=10, source=df1)
show(p)
